# %% [markdown]
# ## window安装OpenCV
# * pip install numpy
# * pip install matplotlib
# * pip install opencv-contrib-python

# %%
# 验证OpenCV是否安装成功
import cv2
print(cv2.__version__)
# Out:
# 4.4.0

# %% [markdown]
# ## 读取图片

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
# 读取图片
image = cv2.imread("logo.jpg") # 彩色图片，返回的是一个三维numpy数组
plt.imshow(image[:,:,::-1],cmap='gray')  #OpenCV颜色模式是BGR，而matplotlib的颜色模式是RGB
plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image,cmap='gray') 
plt.show()

# %% [markdown]
# #### OpenCV图像的左上角坐标为(0,0)

# %%
logo = cv2.imread('logo.jpg')
logo.shape # 三维数组
# Out:
# (99, 82, 3)

# %%
gray_logo = cv2.imread('logo.jpg',cv2.IMREAD_GRAYSCALE) #灰度模式打开
gray_logo.shape #二维数组
# Out:
# (99, 82)

# %%
plt.imshow(gray_logo,cmap='gray')

# %%
# 修改像素
gray_logo2 = gray_logo.copy()
gray_logo2[:,[i for i in range(80) if i%20 == 0]] = 0
plt.imshow(gray_logo2,cmap='gray')

# %% [markdown]
# ## 分离颜色通道

# %%
# OpenCV读取的图片颜色顺序是BGR
logo = cv2.imread('logo.jpg')
B,G,R = cv2.split(logo)
# 以RGB顺序融合通道
merged_img = cv2.merge([R,G,B])

# 显示两张图片
plt.subplot(121)
plt.imshow(logo)
plt.subplot(122)
plt.imshow(merged_img) # 颜色通道修改后才能正确显示

# %% [markdown]
# ## 组合两张图片

# %%
img = np.concatenate((logo,merged_img),axis=1) #拼接两个数组
plt.imshow(img)

# %% [markdown]
# >使用OpenCV的split方法速度很慢,推荐使用numpy的切片方法

# %%
# 写入图片
cv2.imwrite('logo_gray.jpg',gray_logo)
# Out:
# True

# %% [markdown]
# ## 使用cv2.COLOR_BGR2GRAY转换颜色模式

# %%
logo.shape
# Out:
# (99, 82, 3)

# %%
gray_logo = cv2.cvtColor(logo,cv2.COLOR_BGR2GRAY)
print(gray_logo.shape)
plt.imshow(gray_logo,cmap='gray')
# Out:
# (99, 82)

# %%
capture = cv2.VideoCapture(0)
print(capture.isOpened())
ret,frame = capture.read()
plt.imshow(frame[:,:,::-1])
# frame
# Out:
# True

# %%
# 打印capture对象的一些属性
print(f'WIDTH:{capture.get(cv2.CAP_PROP_FRAME_WIDTH)},HEIGHT:{capture.get(cv2.CAP_PROP_FRAME_HEIGHT)}')
# Out:
# WIDTH:640.0,HEIGHT:480.0

# %%
# 完整捕捉摄像头图片
capture = cv2.VideoCapture(0)
if not capture.isOpened():
    print('摄像头没有正确连接！')
    
ret,frame = capture.read() # 读取一帧图片
if ret:
    plt.imshow(frame[:,:,::-1],cmap='gray')

capture.release()
